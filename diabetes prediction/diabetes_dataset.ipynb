# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt=pd.read_csv('diabetes-dataset.csv')

# %%
dt.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
dt.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# ...

# %%
sns.heatmap(dt.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(dt.corr())
# Out:
# <Axes: >

# %%
dt.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
dt.BMI.unique()
# Out:
# array([33.6, 38.2, 44.2, 42.3, 40.7, 46.5, 25.6, 26.1, 36.8, 33.5, 32.8,
#        28.9,  0. , 26.6, 26. , 30.1, 25.1, 29.3, 25.2, 37.2, 39. , 33.3,
#        37.3, 36.5, 28.6, 30.4, 25. , 29.7, 22.1, 24.2, 27.3, 31.6, 27.6,
#        24. , 33.2, 32.9, 37.1, 34. , 40.2, 22.7, 45.4, 27.4, 42. , 28. ,
#        39.1, 19.4, 24.4, 33.7, 34.7, 23. , 37.7, 46.8, 40.5, 41.5, 25.4,
#        29. , 32.5, 42.7, 19.6, 43.4, 35.1, 32. , 24.7, 32.6, 43.2, 22.4,
#        24.6, 48.8, 32.4, 36.6, 38.5, 26.5, 19.1, 46.7, 23.8, 33.9, 20.4,
#        28.7, 49.7, 22.5, 39.6, 29.5, 34.3, 37.4, 31.2, 30.5, 28.2, 23.2,
#        53.2, 34.2, 26.8, 55. , 42.9, 34.5, 27.9, 38.3, 21.1, 33.8, 30.8,
#        36.9, 39.5, 21.9, 40.6, 47.9, 50. , 40.9, 29.9, 29.6, 31.9, 28.4,
#        35.4, 43.5, 32.7, 67.1, 45. , 34.9, 27.7, 35.9, 22.6, 33.1, 52.3,
#        39.4, 24.3, 22.9, 34.8, 30.9, 31. , 40.1, 23.9, 37.5, 35.5, 42.8,
#        42.6, 41.8, 35.8, 30. , 37.8, 34.6, 28.8, 23.6, 35.7, 36.7, 45.2,
# ...

# %%
dt.DiabetesPedigreeFunction.unique()
# Out:
# array([0.127, 0.233, 0.63 , 0.365, 0.536, 1.159, 0.294, 0.551, 0.629,
#        0.292, 0.145, 1.144, 0.174, 0.304, 0.547, 0.163, 0.839, 0.313,
#        0.267, 0.727, 0.738, 0.238, 0.263, 0.314, 0.692, 0.968, 0.409,
#        0.297, 0.207, 0.2  , 0.525, 0.154, 0.268, 0.512, 0.966, 0.42 ,
#        0.665, 0.503, 1.39 , 0.271, 0.696, 0.235, 0.721, 1.893, 0.564,
#        0.586, 0.344, 0.305, 0.491, 0.526, 0.342, 0.467, 0.718, 0.248,
#        0.254, 0.962, 1.781, 0.173, 0.27 , 0.587, 0.699, 0.258, 0.203,
#        0.855, 0.845, 0.334, 0.189, 0.867, 0.411, 0.583, 0.231, 0.396,
#        0.14 , 0.391, 0.37 , 0.307, 0.102, 0.767, 0.237, 0.227, 0.698,
#        0.178, 0.324, 0.153, 0.165, 0.443, 0.261, 0.277, 0.761, 0.255,
#        0.13 , 0.323, 0.356, 0.325, 1.222, 0.179, 0.262, 0.283, 0.93 ,
#        0.801, 0.287, 0.336, 0.247, 0.199, 0.543, 0.192, 0.588, 0.539,
#        0.22 , 0.654, 0.223, 0.759, 0.26 , 0.404, 0.186, 0.278, 0.496,
# ...

# %%
dt['BMI']=dt['BMI'].replace('?',np.nan)
dt['DiabetesPedigreeFunction']=dt['DiabetesPedigreeFunction'].replace('?',np.nan)

# %%
dt['Outcome'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Outcome'>

# %%
#spliting
x=dt.drop('Outcome',axis=1)
y=dt['Outcome']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test ,y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_sc= sc.fit_transform(x_train)
x_test_sc= sc.transform(x_test)

# %%
#model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

model.fit(x_train_sc,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(x_test_sc)
accuracy_score(y_test,y_pred)
# Out:
# 0.79

# %%
round(model.score(x_test_sc,y_test)*100,0)
# Out:
# 79.0
